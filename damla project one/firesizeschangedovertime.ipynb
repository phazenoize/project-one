# %%
#dependencies and Setup
import csv
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path

plt.close("all")


# Load the CSV file 
wildfires_path = Path("Us_Lightning_Forest_Fires.csv")
wildfires_df = pd.read_csv(wildfires_path)
wildfires_df.head()
# Out:
#    Unnamed: 0  index  FIRE_YEAR   Fire_Date  DISCOVERY_TIME STAT_CAUSE_DESCR  \
# 0           0      1       2004  05-12-2004           845.0        Lightning
# 1           1      3       2004  06-28-2004          1600.0        Lightning
# 2           2      4       2004  06-28-2004          1600.0        Lightning
# 3           3      5       2004  06-30-2004          1800.0        Lightning
# 4           4      6       2004  07-01-2004          1800.0        Lightning
#
#    Days_to_extinguish_fire  CONT_TIME  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE  \
# 0                      0.0     1530.0       0.25               A  38.933056
# 1                      5.0     1400.0       0.10               A  38.559167
# 2                      5.0     1200.0       0.10               A  38.559167
# 3                      1.0     1600.0       0.10               A  38.635278
# 4                      1.0     1400.0       0.10               A  38.688333
#
#     LONGITUDE STATE  FIPS_CODE  FIPS_NAME
# ...

# %%
# Filter the data for Kentucky (KY)
kentucky_df = wildfires_df[wildfires_df["STATE"] == "KY"]

# Group the data by "FIRE_YEAR" and calculate the total fire sizes for each year
fire_size_by_year_ky = kentucky_df.groupby("FIRE_YEAR")["FIRE_SIZE"].sum()

# Create the line plot to visualize the change in fire sizes over time in Kentucky
plt.figure(figsize=(10, 6))
plt.plot(fire_size_by_year_ky.index, fire_size_by_year_ky.values, marker='o', linestyle='-', color='b')
plt.xlabel('Year')
plt.ylabel('Total Fire Size')
plt.title('Change in Fire Sizes Over Time in Kentucky')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Load the CSV file into a pandas DataFrame
wildfires_df = pd.read_csv("Us_Lightning_Forest_Fires.csv")

# Filter the data for the state of Minnesota (MN)
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"]

# Group the fire sizes by year and calculate the total fire size for each year
fire_size_by_year_mn = minnesota_df.groupby("FIRE_YEAR")["FIRE_SIZE"].sum()

# Create a plot table to visualize the trend of fire sizes over time in Minnesota
plt.figure(figsize=(10, 6))
plt.plot(fire_size_by_year_mn.index, fire_size_by_year_mn.values, marker='o', linestyle='-', color='g')
plt.xlabel('Year')
plt.ylabel('Total Fire Size')
plt.title('Fire Sizes Over Time in Minnesota')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for the state of Minnesota (MN)
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"]

# Group the fire sizes by year and calculate the total fire size for each year
fire_size_by_year_mn = minnesota_df.groupby("FIRE_YEAR")["FIRE_SIZE"].sum()

# Create a plot table to visualize the trend of fire sizes over time in Minnesota
plt.figure(figsize=(10, 6))
plt.plot(fire_size_by_year_mn.index, fire_size_by_year_mn.values, marker='o', linestyle='-', color='g')
plt.xlabel('Year')
plt.ylabel('Total Fire Size')
plt.title('Fire Sizes Over Time in Minnesota')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Load the CSV file into a pandas DataFrame
wildfires_df = pd.read_csv("Us_Lightning_Forest_Fires.csv")

# Filter the data for the state of Washington (WA)
washington_df = wildfires_df[wildfires_df["STATE"] == "WA"]

# Group the fire sizes by year and calculate the total fire size for each year
fire_size_by_year_washington = washington_df.groupby("FIRE_YEAR")["FIRE_SIZE"].sum()

# Create a plot table to visualize the trend of fire sizes over time in Washington
plt.figure(figsize=(10, 6))
plt.plot(fire_size_by_year_washington.index, fire_size_by_year_washington.values, marker='o', linestyle='-', color='b')
plt.xlabel('Year')
plt.ylabel('Total Fire Size')
plt.title('Fire Sizes Over Time in Washington')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Load the CSV file into a pandas DataFrame
wildfires_df = pd.read_csv("Us_Lightning_Forest_Fires.csv")

# Filter the data for the state of North Carolina (NC)
nc_df = wildfires_df[wildfires_df["STATE"] == "NC"]

# Group the fire sizes by year and calculate the total fire size for each year
fire_size_by_year_nc = nc_df.groupby("FIRE_YEAR")["FIRE_SIZE"].sum()

# Create a plot table to visualize the trend of fire sizes over time in North Carolina
plt.figure(figsize=(10, 6))
plt.plot(fire_size_by_year_nc.index, fire_size_by_year_nc.values, marker='o', linestyle='-', color='g')
plt.xlabel('Year')
plt.ylabel('Total Fire Size')
plt.title('Fire Sizes Over Time in North Carolina')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Load the CSV file into a pandas DataFrame
wildfires_df = pd.read_csv("Us_Lightning_Forest_Fires.csv")

# Filter the data for the state of North Dakota (ND)
nd_df = wildfires_df[wildfires_df["STATE"] == "ND"]

# Group the fire sizes by year and calculate the total fire size for each year
fire_size_by_year_nd = nd_df.groupby("FIRE_YEAR")["FIRE_SIZE"].sum()

# Create a plot table to visualize the trend of fire sizes over time in North Dakota
plt.figure(figsize=(10, 6))
plt.plot(fire_size_by_year_nd.index, fire_size_by_year_nd.values, marker='o', linestyle='-', color='b')
plt.xlabel('Year')
plt.ylabel('Total Fire Size')
plt.title('Fire Sizes Over Time in North Dakota')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for the state of New Hampshire (NH)
nh_df = wildfires_df[wildfires_df["STATE"] == "NH"]

# Group the fire sizes by year and calculate the total fire size for each year
fire_size_by_year_nh = nh_df.groupby("FIRE_YEAR")["FIRE_SIZE"].sum()

# Create a plot table to visualize the trend of fire sizes over time in New Hampshire
plt.figure(figsize=(10, 6))
plt.plot(fire_size_by_year_nh.index, fire_size_by_year_nh.values, marker='o', linestyle='-', color='g')
plt.xlabel('Year')
plt.ylabel('Total Fire Size')
plt.title('Fire Sizes Over Time in New Hampshire')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for the state of New York (NY)
ny_df = wildfires_df[wildfires_df["STATE"] == "NY"]

# Group the fire sizes by year and calculate the total fire size for each year
fire_size_by_year_ny = ny_df.groupby("FIRE_YEAR")["FIRE_SIZE"].sum()

# Create a plot table to visualize the trend of fire sizes over time in New York
plt.figure(figsize=(10, 6))
plt.plot(fire_size_by_year_ny.index, fire_size_by_year_ny.values, marker='o', linestyle='-', color='b')
plt.xlabel('Year')
plt.ylabel('Total Fire Size')
plt.title('Fire Sizes Over Time in New York')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for the state of Arizona (AZ)
az_df = wildfires_df[wildfires_df["STATE"] == "AZ"]

# Group the fire sizes by year and calculate the total fire size for each year
fire_size_by_year_az = az_df.groupby("FIRE_YEAR")["FIRE_SIZE"].sum()

# Create a plot table to visualize the trend of fire sizes over time in Arizona
plt.figure(figsize=(10, 6))
plt.plot(fire_size_by_year_az.index, fire_size_by_year_az.values, marker='o', linestyle='-', color='g')
plt.xlabel('Year')
plt.ylabel('Total Fire Size')
plt.title('Fire Sizes Over Time in Arizona')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
