# %%
#dependencies and Setup
import csv
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path

plt.close("all")


# Load the CSV file 
wildfires_path = Path("Us_Lightning_Forest_Fires.csv")
wildfires_df = pd.read_csv(wildfires_path)
wildfires_df.head()
# Out:
#    Unnamed: 0  index  FIRE_YEAR   Fire_Date  DISCOVERY_TIME STAT_CAUSE_DESCR  \
# 0           0      1       2004  05-12-2004           845.0        Lightning
# 1           1      3       2004  06-28-2004          1600.0        Lightning
# 2           2      4       2004  06-28-2004          1600.0        Lightning
# 3           3      5       2004  06-30-2004          1800.0        Lightning
# 4           4      6       2004  07-01-2004          1800.0        Lightning
#
#    Days_to_extinguish_fire  CONT_TIME  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE  \
# 0                      0.0     1530.0       0.25               A  38.933056
# 1                      5.0     1400.0       0.10               A  38.559167
# 2                      5.0     1200.0       0.10               A  38.559167
# 3                      1.0     1600.0       0.10               A  38.635278
# 4                      1.0     1400.0       0.10               A  38.688333
#
#     LONGITUDE STATE  FIPS_CODE  FIPS_NAME
# ...

# %%
# Filter the data for the state of Washington and select the necessary columns
washington_df = wildfires_df[wildfires_df["STATE"] == "WA"]

# Calculate the total number of fires by year
total_fires_by_year = washington_df["FIRE_YEAR"].value_counts().sort_index()

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(total_fires_by_year.index, total_fires_by_year.values, color='skyblue')
plt.xlabel('Year')
plt.ylabel('Total Number of Fires')
plt.title('Total Number of Fires in Washington by Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for the state of Kentucky and select the necessary columns
kentucky_df = wildfires_df[wildfires_df["STATE"] == "KY"]

# Calculate the total number of fires by year
total_fires_by_year = kentucky_df["FIRE_YEAR"].value_counts().sort_index()

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(total_fires_by_year.index, total_fires_by_year.values, color='orange')
plt.xlabel('Year')
plt.ylabel('Total Number of Fires')
plt.title('Total Number of Fires in Kentucky by Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for the state of Minnesota and select the necessary columns
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"]

# Calculate the total number of fires by year
total_fires_by_year = minnesota_df["FIRE_YEAR"].value_counts().sort_index()

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(total_fires_by_year.index, total_fires_by_year.values, color='green')
plt.xlabel('Year')
plt.ylabel('Total Number of Fires')
plt.title('Total Number of Fires in Minnesota by Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for the state of Utah and select the necessary columns
utah_df = wildfires_df[wildfires_df["STATE"] == "UT"]

# Calculate the total number of fires by year
total_fires_by_year = utah_df["FIRE_YEAR"].value_counts().sort_index()

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(total_fires_by_year.index, total_fires_by_year.values, color='orange')
plt.xlabel('Year')
plt.ylabel('Total Number of Fires')
plt.title('Total Number of Fires in Utah by Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for the state of North Carolina and select the necessary columns
north_carolina_df = wildfires_df[wildfires_df["STATE"] == "NC"]

# Calculate the total number of fires by year
total_fires_by_year = north_carolina_df["FIRE_YEAR"].value_counts().sort_index()

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(total_fires_by_year.index, total_fires_by_year.values, color='green')
plt.xlabel('Year')
plt.ylabel('Total Number of Fires')
plt.title('Total Number of Fires in North Carolina by Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for the state of North Dakota and select the necessary columns
north_dakota_df = wildfires_df[wildfires_df["STATE"] == "ND"]

# Calculate the total number of fires by year
total_fires_by_year = north_dakota_df["FIRE_YEAR"].value_counts().sort_index()

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(total_fires_by_year.index, total_fires_by_year.values, color='blue')
plt.xlabel('Year')
plt.ylabel('Total Number of Fires')
plt.title('Total Number of Fires in North Dakota by Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for the state of New Hampshire and select the necessary columns
new_hampshire_df = wildfires_df[wildfires_df["STATE"] == "NH"]

# Calculate the total number of fires by year
total_fires_by_year = new_hampshire_df["FIRE_YEAR"].value_counts().sort_index()

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(total_fires_by_year.index, total_fires_by_year.values, color='purple')
plt.xlabel('Year')
plt.ylabel('Total Number of Fires')
plt.title('Total Number of Fires in New Hampshire by Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for the state of New York and select the necessary columns
new_york_df = wildfires_df[wildfires_df["STATE"] == "NY"]

# Calculate the total number of fires by year
total_fires_by_year = new_york_df["FIRE_YEAR"].value_counts().sort_index()

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(total_fires_by_year.index, total_fires_by_year.values, color='blue')
plt.xlabel('Year')
plt.ylabel('Total Number of Fires')
plt.title('Total Number of Fires in New York by Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for the state of Arizona and select the necessary columns
arizona_df = wildfires_df[wildfires_df["STATE"] == "AZ"]

# Calculate the total number of fires by year
total_fires_by_year = arizona_df["FIRE_YEAR"].value_counts().sort_index()

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(total_fires_by_year.index, total_fires_by_year.values, color='orange')
plt.xlabel('Year')
plt.ylabel('Total Number of Fires')
plt.title('Total Number of Fires in Arizona by Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
