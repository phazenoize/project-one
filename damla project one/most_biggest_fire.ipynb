# %%
#dependencies and setup
import csv
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path
  
plt.close("all")

# %%
# Load the CSV file 
wildfires_path = Path("Us_Lightning_Forest_Fires.csv")
wildfires_df = pd.read_csv(wildfires_path)
wildfires_df.head()
# Out:
#    Unnamed: 0  index  FIRE_YEAR   Fire_Date  DISCOVERY_TIME STAT_CAUSE_DESCR  \
# 0           0      1       2004  05-12-2004           845.0        Lightning
# 1           1      3       2004  06-28-2004          1600.0        Lightning
# 2           2      4       2004  06-28-2004          1600.0        Lightning
# 3           3      5       2004  06-30-2004          1800.0        Lightning
# 4           4      6       2004  07-01-2004          1800.0        Lightning
#
#    Days_to_extinguish_fire  CONT_TIME  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE  \
# 0                      0.0     1530.0       0.25               A  38.933056
# 1                      5.0     1400.0       0.10               A  38.559167
# 2                      5.0     1200.0       0.10               A  38.559167
# 3                      1.0     1600.0       0.10               A  38.635278
# 4                      1.0     1400.0       0.10               A  38.688333
#
#     LONGITUDE STATE  FIPS_CODE  FIPS_NAME
# ...

# %%
# Group the data by "STATE" and calculate the total number of fires for each state
fires_by_state = wildfires_df['STATE'].value_counts()

# %%
# Group the data by "STATE" and calculate the maximum fire size for each state
max_fire_size_by_state = wildfires_df.groupby('STATE')['FIRE_SIZE'].max()

# %%
#Bu kod, her eyaletteki toplam yangın sayısını ve her eyaletteki en büyük yangınların boyutunu gösteren iki ayrı bar plot oluşturacaktır. Mavi çubuklar, eyaletlerdeki toplam yangın sayısını gösterirken, turuncu çubuklar eyaletlerdeki en büyük yangınların boyutunu gösterecektir.

#Bu grafiklerle, hangi eyaletlerde en çok ve en büyük yangınların olduğunu kolayca görebilirsiniz.

# %%
# Create a bar plot to visualize the total number of fires by state
plt.figure(figsize=(12, 6))
fires_by_state.plot(kind='bar', color='skyblue')
plt.title('Total Number of Fires by State', fontsize=16)
plt.xlabel('State', fontsize=14)
plt.ylabel('Number of Fires', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Create a bar plot to visualize the maximum fire size by state
plt.figure(figsize=(12, 6))
max_fire_size_by_state.plot(kind='bar', color='orange')
plt.title('Maximum Fire Size by State', fontsize=16)
plt.xlabel('State', fontsize=14)
plt.ylabel('Maximum Fire Size (acres)', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Filter data for Arizona
arizona_df = wildfires_df[wildfires_df["STATE"] == "AZ"]

# Sort the data by FIRE_SIZE in descending order and select the top 5 rows
biggest_fires = arizona_df.nlargest(5, "FIRE_SIZE")

# Plot bar chart for the top 5 biggest fires in Arizona
plt.figure(figsize=(10, 6))
plt.bar(biggest_fires["Fire_Date"], biggest_fires["FIRE_SIZE"], color='salmon')
plt.xlabel('Fire Date')
plt.ylabel('Fire Size')
plt.title('Top 5 Biggest Fires in Arizona')
plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Filter data for Minnesota
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"]

# Sort the data by FIRE_SIZE in descending order and select the top 5 rows
biggest_fires_mn = minnesota_df.nlargest(5, "FIRE_SIZE")

# Create a scatter plot for the top 5 biggest fires in Minnesota
plt.figure(figsize=(10, 6))
plt.scatter(biggest_fires_mn["Fire_Date"], biggest_fires_mn["FIRE_SIZE"], c=biggest_fires_mn["FIRE_SIZE"], cmap='YlOrRd', s=1000)
plt.colorbar(label="Fire Size")
plt.xlabel('Fire Date')
plt.ylabel('Fire Size')
plt.title('Top 5 Biggest Fires in Minnesota')
plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Filter data for Washington
washington_df = wildfires_df[wildfires_df["STATE"] == "WA"]

# Sort the data by FIRE_SIZE in descending order and select the top 5 rows
biggest_fires_wa = washington_df.nlargest(5, "FIRE_SIZE")

# Create a bar plot for the top 5 biggest fires in Washington
plt.figure(figsize=(10, 6))
plt.bar(biggest_fires_wa["Fire_Date"], biggest_fires_wa["FIRE_SIZE"], color='orange')
plt.xlabel('Fire Date')
plt.ylabel('Fire Size')
plt.title('Top 5 Biggest Fires in Washington')
plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Filter data for Minnesota state
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"]

# Sort the data by FIRE_SIZE in descending order and select the top 5 rows
largest_fires = minnesota_df.nlargest(5, "FIRE_SIZE")

# Create a bar plot for the top 5 largest wildfires in Minnesota
plt.figure(figsize=(10, 6))
plt.bar(largest_fires["Fire_Date"], largest_fires["FIRE_SIZE"], color='orange')
plt.xlabel('Fire Date')
plt.ylabel('Fire Size')
plt.title('Top 5 Largest Wildfires in Minnesota')
plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Filter data for Minnesota state
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"]

# Sort the data by FIRE_SIZE in descending order and select the top 5 rows
largest_fires = minnesota_df.nlargest(5, "FIRE_SIZE")

# Create a bar plot for the top 5 largest wildfires in Minnesota
plt.figure(figsize=(10, 6))
plt.bar(largest_fires["Fire_Date"], largest_fires["FIRE_SIZE"], color='orange')
plt.xlabel('Fire Date')
plt.ylabel('Fire Size')
plt.title('Top 5 Largest Wildfires in Minnesota')
plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
file_path = "Us_Lightning_Forest_Fires.csv"
wildfires_df = pd.read_csv(file_path)

# Filter data for Minnesota state
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"]

# Sort the data by FIRE_SIZE in descending order and select the top 5 rows
largest_fires = minnesota_df.nlargest(5, "FIRE_SIZE")

# Create a bar plot for the top 5 largest wildfires in Minnesota
plt.figure(figsize=(10, 6))
plt.bar(largest_fires["Fire_Date"], largest_fires["FIRE_SIZE"], color='orange')
plt.xlabel('Fire Date')
plt.ylabel('Fire Size')
plt.title('Top 5 Largest Wildfires in Minnesota')
plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Minnesota'daki verileri filtrele
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"]

# FIRE_SIZE sütununa göre verileri büyüklük sırasına göre sırala ve en büyük 5 yangını seç
largest_fires = minnesota_df.nlargest(5, "FIRE_SIZE")

# En büyük 5 yangını ekrana bas
print(largest_fires)
# Out:
#         Unnamed: 0    index  FIRE_YEAR   Fire_Date  DISCOVERY_TIME  \
# 225134      225134  1454246       2011  08-18-2011          1558.0
# 9178          9178    16476       2006  07-14-2006          1533.0
# 49831        49831    92120       1996  06-12-1996          1430.0
# 49824        49824    92097       1996  06-14-1996          1212.0
# 9151          9151    16412       2006  09-08-2006          1200.0
#
#        STAT_CAUSE_DESCR  Days_to_extinguish_fire  CONT_TIME  FIRE_SIZE  \
# 225134        Lightning                    102.0     1800.0    92682.0
# 9178          Lightning                     80.0     1200.0    31830.0
# 49831         Lightning                     19.0      600.0     4750.0
# 49824         Lightning                     12.0     1800.0     4130.0
# 9151          Lightning                     52.0     1200.0     4104.0
#
#        FIRE_SIZE_CLASS   LATITUDE  LONGITUDE STATE  FIPS_CODE FIPS_NAME
# ...

# %%
# Minnesota'daki verileri filtrele
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"]

# FIRE_SIZE sütununa göre verileri büyüklük sırasına göre sırala ve en büyük 5 yangını seç
largest_fires = minnesota_df.nlargest(5, "FIRE_SIZE")

# Bar plot'u oluştur
plt.figure(figsize=(10, 6))
plt.bar(largest_fires["Fire_Date"], largest_fires["FIRE_SIZE"], color="salmon")
plt.xlabel("Fire Date")
plt.ylabel("Fire Size")
plt.title("Top 5 Biggest Wildfires in Minnesota")
plt.xticks(rotation=45)
plt.tight_layout()

# Bar plot'u göster
plt.show()

# %%
# Minnessota eyaletine ait yangınları filtreleyelim
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"]

# Yangınları FIRE_SIZE (yangın büyüklüğü) sütununa göre büyükten küçüğe sıralayalım ve en büyük 5 yangını seçelim
largest_fires = minnesota_df.nlargest(5, "FIRE_SIZE")

# Bar plot grafiği oluşturalım
plt.figure(figsize=(10, 6))
plt.bar(largest_fires["Fire_Date"], largest_fires["FIRE_SIZE"], color='orange')
plt.xlabel('Fire Date')
plt.ylabel('Fire Size')
plt.title('Top 5 Largest Wildfires in Minnesota')
plt.xticks(rotation=45)
plt.tight_layout()

# Grafiği gösterelim
plt.show()

# %%
# Minnessota (MN) eyaletine ait verileri filtreleyelim
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"]

# Verileri "FIRE_SIZE" sütununa göre büyüklüğe göre sıralayalım ve en büyük 5 yangını seçelim
top_5_fires = minnesota_df.nlargest(5, "FIRE_SIZE")

# Sonuçları ekrana basalım
print(top_5_fires)
# Out:
#         Unnamed: 0    index  FIRE_YEAR   Fire_Date  DISCOVERY_TIME  \
# 225134      225134  1454246       2011  08-18-2011          1558.0
# 9178          9178    16476       2006  07-14-2006          1533.0
# 49831        49831    92120       1996  06-12-1996          1430.0
# 49824        49824    92097       1996  06-14-1996          1212.0
# 9151          9151    16412       2006  09-08-2006          1200.0
#
#        STAT_CAUSE_DESCR  Days_to_extinguish_fire  CONT_TIME  FIRE_SIZE  \
# 225134        Lightning                    102.0     1800.0    92682.0
# 9178          Lightning                     80.0     1200.0    31830.0
# 49831         Lightning                     19.0      600.0     4750.0
# 49824         Lightning                     12.0     1800.0     4130.0
# 9151          Lightning                     52.0     1200.0     4104.0
#
#        FIRE_SIZE_CLASS   LATITUDE  LONGITUDE STATE  FIPS_CODE FIPS_NAME
# ...

# %%
# Verileri "FIRE_SIZE" sütununa göre büyüklüğe göre sıralayalım ve en büyük 5 yangını seçelim
top_5_fires = minnesota_df.nlargest(5, "FIRE_SIZE")

# Bar plot'u oluşturalım
plt.figure(figsize=(10, 6))
plt.bar(top_5_fires["Fire_Date"], top_5_fires["FIRE_SIZE"], color='salmon')
plt.xlabel('Fire Date')
plt.ylabel('Fire Size')
plt.title('Top 5 Biggest Forest Fires in Minnesota')
plt.xticks(rotation=45)
plt.tight_layout()

# Grafiği gösterelim
plt.show()

# %%
# Minnessota eyaletine ait verileri filtreleyelim
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"]

# "FIRE_SIZE" sütununa göre büyükten küçüğe sıralayalım ve en büyük 5 yangını seçelim
top_5_fires = minnesota_df.nlargest(5, "FIRE_SIZE")

# Bar plot'u oluşturalım
plt.figure(figsize=(10, 6))
plt.bar(top_5_fires["FIRE_NAME"], top_5_fires["FIRE_SIZE"], color='salmon')
plt.xlabel('Fire Name')
plt.ylabel('Fire Size')
plt.title('Top 5 Biggest Forest Fires in Minnesota')
plt.xticks(rotation=45)
plt.tight_layout()

# Grafiği gösterelim
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\damla\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\damla\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\damla\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FIRE_NAME'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Minnessota eyaletine ait verileri filtreleyelim
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"]

# "FIRE_SIZE" sütununa göre büyükten küçüğe sıralayalım ve en büyük 5 yangını seçelim
top_5_fires = minnesota_df.nlargest(5, "FIRE_SIZE")

# Bar plot'u oluşturalım
plt.figure(figsize=(10, 6))
plt.bar(top_5_fires["FIRE_NAME"], top_5_fires["FIRE_SIZE"], color='salmon')
plt.xlabel('Fire Name')
plt.ylabel('Fire Size')
plt.title('Top 5 Biggest Forest Fires in Minnesota')
plt.xticks(rotation=45)
plt.tight_layout()

# Grafiği gösterelim
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\damla\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\damla\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\damla\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FIRE_NAME'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Minnessota eyaletine ait verileri filtreleyelim
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"]

# Verileri inceleyelim
print(minnesota_df.head())

# "FIRE_NAME" sütunu olup olmadığını kontrol edelim
if "FIRE_NAME" in minnesota_df.columns:
    # "FIRE_SIZE" sütununa göre büyükten küçüğe sıralayalım ve en büyük 5 yangını seçelim
    top_5_fires = minnesota_df.nlargest(5, "FIRE_SIZE")

    # Bar plot'u oluşturalım
    plt.figure(figsize=(10, 6))
    plt.bar(top_5_fires["FIRE_NAME"], top_5_fires["FIRE_SIZE"], color='salmon')
    plt.xlabel('Fire Name')
    plt.ylabel('Fire Size')
    plt.title('Top 5 Biggest Forest Fires in Minnesota')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Grafiği gösterelim
    plt.show()
else:
    print("FIRE_NAME column not found in the data.")
# Out:
#      Unnamed: 0  index  FIRE_YEAR   Fire_Date  DISCOVERY_TIME  \
# 277         277    611       2005  07-30-2005          1705.0
# 477         477    957       2005  07-20-2005          1300.0
# 478         478    960       2005  07-20-2005          1100.0
# 479         479    961       2005  07-21-2005          1300.0
# 848         848   1648       2005  08-06-2005          2000.0
#
#     STAT_CAUSE_DESCR  Days_to_extinguish_fire  CONT_TIME  FIRE_SIZE  \
# 277        Lightning                      2.0      730.0       0.20
# 477        Lightning                      2.0     1800.0       2.00
# 478        Lightning                      1.0     1030.0       0.35
# 479        Lightning                      2.0     1030.0       1.00
# 848        Lightning                      1.0     1730.0       0.30
#
#     FIRE_SIZE_CLASS   LATITUDE  LONGITUDE STATE  FIPS_CODE  FIPS_NAME
# 277               A  48.121111 -91.149722    MN       75.0       Lake
# ...

# %%
# Minnessota eyaletine ait verileri filtreleyelim
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"]

# "FIRE_NAME" sütunu olup olmadığını kontrol edelim
if "FIRE_NAME" in minnesota_df.columns:
    # "FIRE_SIZE" sütununa göre büyükten küçüğe sıralayalım ve en büyük 5 yangını seçelim
    top_5_fires = minnesota_df.nlargest(5, "FIRE_SIZE")

    # Bar plot'u oluşturalım
    plt.figure(figsize=(10, 6))
    plt.bar(top_5_fires["FIRE_NAME"], top_5_fires["FIRE_SIZE"], color='salmon')
    plt.xlabel('Fire Name')
    plt.ylabel('Fire Size')
    plt.title('Top 5 Biggest Forest Fires in Minnesota')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Grafiği gösterelim
    plt.show()

# %%
# Minnessota eyaletine ait verileri filtreleyelim
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"]

# "FIRE_YEAR" sütununa göre yangınları gruplayalım ve büyükten küçüğe sıralayalım
top_5_fires = minnesota_df.groupby("FIRE_YEAR").sum().nlargest(5, "FIRE_SIZE")

# Bar plot'u oluşturalım
plt.figure(figsize=(10, 6))
plt.bar(top_5_fires.index, top_5_fires["FIRE_SIZE"], color='salmon')
plt.xlabel('Year')
plt.ylabel('Total Fire Size')
plt.title('Top 5 Years with the Biggest Forest Fires in Minnesota')
plt.xticks(rotation=45)
plt.tight_layout()

# Grafiği gösterelim
plt.show()
# Out:
# C:\Users\damla\AppData\Local\Temp\ipykernel_6320\1304278737.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   top_5_fires = minnesota_df.groupby("FIRE_YEAR").sum().nlargest(5, "FIRE_SIZE")
