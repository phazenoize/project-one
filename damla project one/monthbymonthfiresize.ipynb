# %%
#dependencies and Setup
import csv
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path

plt.close("all")


# Load the CSV file 
wildfires_path = Path("Us_Lightning_Forest_Fires.csv")
wildfires_df = pd.read_csv(wildfires_path)
wildfires_df.head()
# Out:
#    Unnamed: 0  index  FIRE_YEAR   Fire_Date  DISCOVERY_TIME STAT_CAUSE_DESCR  \
# 0           0      1       2004  05-12-2004           845.0        Lightning
# 1           1      3       2004  06-28-2004          1600.0        Lightning
# 2           2      4       2004  06-28-2004          1600.0        Lightning
# 3           3      5       2004  06-30-2004          1800.0        Lightning
# 4           4      6       2004  07-01-2004          1800.0        Lightning
#
#    Days_to_extinguish_fire  CONT_TIME  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE  \
# 0                      0.0     1530.0       0.25               A  38.933056
# 1                      5.0     1400.0       0.10               A  38.559167
# 2                      5.0     1200.0       0.10               A  38.559167
# 3                      1.0     1600.0       0.10               A  38.635278
# 4                      1.0     1400.0       0.10               A  38.688333
#
#     LONGITUDE STATE  FIPS_CODE  FIPS_NAME
# ...

# %%
# Filter the data for Arizona (AZ) and select the necessary columns
arizona_df = wildfires_df[wildfires_df["STATE"] == "AZ"][["FIRE_YEAR", "Fire_Date", "FIRE_SIZE"]]

# Convert the "Fire_Date" column to datetime data type
arizona_df["Fire_Date"] = pd.to_datetime(arizona_df["Fire_Date"])

# Calculate the total fire sizes by month and fill missing values with 0
monthly_fire_sizes_arizona = arizona_df.groupby(arizona_df["Fire_Date"].dt.month)["FIRE_SIZE"].sum().reindex(range(1, 13), fill_value=0)

# Define the month names
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(months, monthly_fire_sizes_arizona, color='blue')
plt.xlabel('Month')
plt.ylabel('Total Fire Size')
plt.title('Arizona Wildfires: Fire Size by Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# North Carolina (Kuzey Karolina) eyaletini filtreleyelim ve gerekli sütunları alalım
north_carolina_df = wildfires_df[wildfires_df["STATE"] == "NC"][["FIRE_YEAR", "Fire_Date", "FIRE_SIZE"]]

# Fire_Date sütununu datetime veri tipine çevirelim
north_carolina_df["Fire_Date"] = pd.to_datetime(north_carolina_df["Fire_Date"])

# Aylara göre fire size değerlerini hesaplayalım ve eksik değerleri 0 ile dolduralım
monthly_fire_sizes_nc = north_carolina_df.groupby(north_carolina_df["Fire_Date"].dt.month)["FIRE_SIZE"].sum().reindex(range(1, 13), fill_value=0)

# Ay isimlerini tamamlayalım
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Bar plot'u oluşturalım
plt.figure(figsize=(10, 6))
plt.bar(months, monthly_fire_sizes_nc, color='green')
plt.xlabel('Month')
plt.ylabel('Total Fire Size')
plt.title('North Carolina Wildfires: Fire Size by Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Kentucky eyaletini filtreleyelim ve gerekli sütunları alalım
kentucky_df = wildfires_df[wildfires_df["STATE"] == "KY"][["FIRE_YEAR", "Fire_Date", "FIRE_SIZE"]]

# Fire_Date sütununu datetime veri tipine çevirelim
kentucky_df["Fire_Date"] = pd.to_datetime(kentucky_df["Fire_Date"])

# Aylara göre fire size değerlerini hesaplayalım ve eksik değerleri 0 ile dolduralım
monthly_fire_sizes_ky = kentucky_df.groupby(kentucky_df["Fire_Date"].dt.month)["FIRE_SIZE"].sum().reindex(range(1, 13), fill_value=0)

# Ay isimlerini tamamlayalım
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Bar plot'u oluşturalım
plt.figure(figsize=(10, 6))
plt.bar(months, monthly_fire_sizes_ky, color='blue')
plt.xlabel('Month')
plt.ylabel('Total Fire Size')
plt.title('Kentucky Wildfires: Fire Size by Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for Minnesota (MN) and select the necessary columns
north_dakota_df = wildfires_df[wildfires_df["STATE"] == "ND"][["FIRE_YEAR", "Fire_Date", "FIRE_SIZE"]]


# Convert the "Fire_Date" column to datetime data type
north_dakota_df["Fire_Date"] = pd.to_datetime(north_dakota_df["Fire_Date"])

# Calculate the total fire sizes by month and fill missing values with 0
monthly_fire_sizes_nd = north_dakota_df.groupby(north_dakota_df["Fire_Date"].dt.month)["FIRE_SIZE"].sum().reindex(range(1, 13), fill_value=0)

# Define the month names

months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Bar plot'u oluşturalım
plt.figure(figsize=(10, 6))
plt.bar(months, monthly_fire_sizes_nd, color='purple')
plt.xlabel('Month')
plt.ylabel('Total Fire Size')
plt.title('North Dakota Wildfires: Fire Size by Month')
plt.xticks(rotation=45)
plt.tight_layout()

# %%
# Filter the data for Minnesota (MN) and select the necessary columns
minnesota_df = wildfires_df[wildfires_df["STATE"] == "MN"][["FIRE_YEAR", "Fire_Date", "FIRE_SIZE"]]

# Convert the "Fire_Date" column to datetime data type
minnesota_df["Fire_Date"] = pd.to_datetime(minnesota_df["Fire_Date"])

# Calculate the total fire sizes by month and fill missing values with 0
monthly_fire_sizes_minnesota = minnesota_df.groupby(minnesota_df["Fire_Date"].dt.month)["FIRE_SIZE"].sum().reindex(range(1, 13), fill_value=0)

# Define the month names
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(months, monthly_fire_sizes_minnesota, color='purple')
plt.xlabel('Month')
plt.ylabel('Total Fire Size')
plt.title('Minnesota Wildfires: Fire Size by Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for Minnesota (MN) and select the necessary columns

washington_df = wildfires_df[wildfires_df["STATE"] == "WA"][["FIRE_YEAR", "Fire_Date", "FIRE_SIZE"]]

# Convert the "Fire_Date" column to datetime data type
washington_df["Fire_Date"] = pd.to_datetime(washington_df["Fire_Date"])


# Calculate the total fire sizes by month and fill missing values with 0
monthly_fire_sizes_wa = washington_df.groupby(washington_df["Fire_Date"].dt.month)["FIRE_SIZE"].sum().reindex(range(1, 13), fill_value=0)

# Define the month names
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Creat the bar oluşturalım
plt.figure(figsize=(10, 6))
plt.bar(months, monthly_fire_sizes_wa, color='purple')
plt.xlabel('Month')
plt.ylabel('Total Fire Size')
plt.title('Washington Wildfires: Fire Size by Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for New Hampshire (NH) and select the necessary columns
nh_df = wildfires_df[wildfires_df["STATE"] == "NH"][["FIRE_YEAR", "Fire_Date", "FIRE_SIZE"]]

# Convert the "Fire_Date" column to datetime data type
nh_df["Fire_Date"] = pd.to_datetime(nh_df["Fire_Date"])

# Calculate the total fire sizes by month and fill missing values with 0
monthly_fire_sizes_nh = nh_df.groupby(nh_df["Fire_Date"].dt.month)["FIRE_SIZE"].sum().reindex(range(1, 13), fill_value=0)

# Define the month names
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(months, monthly_fire_sizes_nh, color='blue')
plt.xlabel('Month')
plt.ylabel('Total Fire Size')
plt.title('New Hampshire Wildfires: Fire Size by Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for New York (NY) and select the necessary columns
ny_df = wildfires_df[wildfires_df["STATE"] == "NY"][["FIRE_YEAR", "Fire_Date", "FIRE_SIZE"]]

# Convert the "Fire_Date" column to datetime data type
ny_df["Fire_Date"] = pd.to_datetime(ny_df["Fire_Date"])

# Calculate the total fire sizes by month and fill missing values with 0
monthly_fire_sizes_ny = ny_df.groupby(ny_df["Fire_Date"].dt.month)["FIRE_SIZE"].sum().reindex(range(1, 13), fill_value=0)

# Define the month names
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(months, monthly_fire_sizes_ny, color='purple')
plt.xlabel('Month')
plt.ylabel('Total Fire Size')
plt.title('New York Wildfires: Fire Size by Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter the data for Utah (UT) and select the necessary columns
utah_df = wildfires_df[wildfires_df["STATE"] == "UT"][["FIRE_YEAR", "Fire_Date", "FIRE_SIZE"]]

# Convert the "Fire_Date" column to datetime data type
utah_df["Fire_Date"] = pd.to_datetime(utah_df["Fire_Date"])

# Calculate the total fire sizes by month and fill missing values with 0
monthly_fire_sizes_utah = utah_df.groupby(utah_df["Fire_Date"].dt.month)["FIRE_SIZE"].sum().reindex(range(1, 13), fill_value=0)

# Define the month names
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(months, monthly_fire_sizes_utah, color='blue')
plt.xlabel('Month')
plt.ylabel('Total Fire Size')
plt.title('Utah Wildfires: Fire Size by Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
